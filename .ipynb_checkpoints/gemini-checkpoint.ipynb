# %%
# !pip install pandas seaborn google-cloud-aiplatform tdqm
# !gcloud auth application-default login
# Out:
# Requirement already satisfied: pandas in ./env/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: seaborn in ./env/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: google-cloud-aiplatform in ./env/lib/python3.12/site-packages (1.48.0)
# Requirement already satisfied: tdqm in ./env/lib/python3.12/site-packages (0.0.1)
# Requirement already satisfied: numpy>=1.26.0 in ./env/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./env/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./env/lib/python3.12/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in ./env/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.18.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.29.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (4.25.3)
# Requirement already satisfied: packaging>=14.3 in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (24.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.16.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (3.21.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.0.4)
# Requirement already satisfied: pydantic<3 in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied: docstring-parser<1 in ./env/lib/python3.12/site-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: tqdm in ./env/lib/python3.12/site-packages (from tdqm) (4.66.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./env/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.63.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in ./env/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in ./env/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.62.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in ./env/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.62.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./env/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./env/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./env/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in ./env/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in ./env/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in ./env/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in ./env/lib/python3.12/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=8 in ./env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./env/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: annotated-types>=0.4.0 in ./env/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in ./env/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./env/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (4.11.0)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./env/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2024.2.2)
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login&state=Jz5ZZsomUYF3tb1wOOCE0o9tzg3Tfx&access_type=offline&code_challenge=rQfmvkJHVbNXKh0qpYVAQPn5tJOIba1DdipwWF9ypZ4&code_challenge_method=S256
#
#
# Credentials saved to file: [/Users/alistairkeiller/.config/gcloud/application_default_credentials.json]
#
# These credentials will be used by any library that requests Application Default Credentials (ADC).
# WARNING:
# Cannot find a quota project to add to ADC. You might receive a "quota exceeded" or "API not enabled" error. Run $ gcloud auth application-default set-quota-project to add a quota project.
#
#
# Updates are available for some Google Cloud CLI components.  To install them,
# please run:
#   $ gcloud components update

# %%
import pandas as pd
import glob
import csv
import re
import seaborn as sns
import seaborn.objects as so
import matplotlib.pyplot as plt
import google.generativeai as genai
import os
import time
from tqdm import tqdm
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, FinishReason
import vertexai.preview.generative_models as generative_models

# %%
vertexai.init(project="yolo-410704", location="us-central1")
gemini_pro_long = GenerativeModel("gemini-1.5-pro-preview-0409")
gemini_pro = GenerativeModel("gemini-pro")

# %%
dfs = []


def read_file(file):
    try:
        return open(directory + file + ".txt", "r").read()
    except:
        return None


for info_file in glob.glob("RusLit/**/info.csv", recursive=True):
    try:
        directory = info_file[:-8]
        info = pd.read_csv(info_file)
        info["author"] = directory.split("/")[2]
        info["type"] = directory.split("/")[1]
        info["text"] = info["name"].map(read_file)
        dfs.append(info)
    except:
        pass

df = pd.concat(dfs, ignore_index=True).dropna()
df["year"] = (
    df["year"].astype(str).map(lambda x: x.split("-")[0].split(".")[0]).astype(int)
)

# %%
retry_limit = 5
def get_genres(text):
    methods = [gemini_pro_long.generate_content, gemini_pro.generate_content]
    prompt = (
        text
        + "Please provide a comma-separated list of single-word genres that best describe the text above: "
    )

    for method in methods:
        for attempt in range(retry_limit):
            try:
                response = method(prompt)
                return response.candidates[0].content.parts[0].text
            except Exception as e:
                print(f"Error: {e}")
                time.sleep(60)

    return None


try:
    df = pd.read_csv("test.csv")
except:
    df["genres"] = [
        get_genres(text) for text in tqdm(df["text"], desc="Generating genres")
    ]
    df.to_csv("test.csv", index=False)
# Out:
# Generating genres:   0%|                                            | 0/330 [00:00<?, ?it/s]/Users/alistairkeiller/russian_lit/env/lib/python3.12/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Generating genres:   2%|▌                                 | 6/330 [01:21<1:12:18, 13.39s/it]
# Error: 500 Internal error encountered.
# Generating genres:   2%|▋                                 | 7/330 [01:42<1:25:12, 15.83s/it]
# Error: 400 Unable to submit request because the input token count is 45735 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:   3%|▉                                 | 9/330 [02:08<1:16:30, 14.30s/it]
# Error: 500 Internal error encountered.
# Generating genres:   3%|█                                | 10/330 [02:29<1:27:17, 16.37s/it]
# Error: 400 Unable to submit request because the input token count is 59135 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  14%|████▌                            | 46/330 [10:34<1:10:51, 14.97s/it]
# Error: 500 Internal error encountered.
# Generating genres:  16%|█████▏                           | 52/330 [11:58<1:04:22, 13.90s/it]
# Error: 500 Internal error encountered.
# Generating genres:  16%|█████▍                           | 54/330 [12:27<1:04:46, 14.08s/it]
# Error: 500 Internal error encountered.
# Generating genres:  19%|██████▊                            | 64/330 [14:43<59:11, 13.35s/it]
# Error: 500 Internal error encountered.
# Generating genres:  20%|██████▌                          | 65/330 [15:08<1:13:53, 16.73s/it]
# Error: 400 Unable to submit request because the input token count is 76390 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  20%|██████▌                          | 66/330 [15:25<1:14:43, 16.98s/it]
# Error: 500 Internal error encountered.
# Generating genres:  20%|██████▋                          | 67/330 [16:06<1:45:33, 24.08s/it]
# Error: 400 Unable to submit request because the input token count is 397257 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  21%|██████▊                          | 68/330 [16:20<1:31:45, 21.01s/it]
# Error: 500 Internal error encountered.
# Generating genres:  21%|██████▉                          | 69/330 [17:10<2:09:35, 29.79s/it]
# Error: 400 Unable to submit request because the input token count is 561295 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  21%|███████                          | 70/330 [17:34<2:01:03, 27.94s/it]
# Error: 400 Unable to submit request because the input token count is 85346 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  22%|███████▏                         | 72/330 [18:04<1:30:51, 21.13s/it]
# Error: 500 Internal error encountered.
# Generating genres:  22%|███████▎                         | 73/330 [18:27<1:33:56, 21.93s/it]
# Error: 400 Unable to submit request because the input token count is 97862 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  22%|███████▍                         | 74/330 [19:09<1:58:34, 27.79s/it]
# Error: 400 Unable to submit request because the input token count is 371297 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  23%|███████▌                         | 75/330 [19:22<1:39:17, 23.36s/it]
# Error: 500 Internal error encountered.
# Generating genres:  23%|███████▌                         | 76/330 [19:46<1:40:05, 23.64s/it]
# Error: 400 Unable to submit request because the input token count is 83750 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  23%|███████▋                         | 77/330 [20:00<1:26:52, 20.60s/it]
# Error: 500 Internal error encountered.
# Generating genres:  24%|███████▊                         | 78/330 [20:24<1:30:35, 21.57s/it]
# Error: 400 Unable to submit request because the input token count is 73983 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  24%|████████                         | 80/330 [21:28<1:55:42, 27.77s/it]
# Error: 500 Internal error encountered.
# Generating genres:  25%|████████                         | 81/330 [21:54<1:52:45, 27.17s/it]
# Error: 500 Internal error encountered.
# Generating genres:  25%|████████▏                        | 82/330 [22:10<1:39:22, 24.04s/it]
# Error: 500 Internal error encountered.
# Generating genres:  27%|████████▉                        | 89/330 [24:25<1:17:05, 19.19s/it]
# Error: 500 Internal error encountered.
# Generating genres:  27%|█████████                        | 90/330 [24:52<1:25:39, 21.42s/it]
# Error: 400 Unable to submit request because the input token count is 132331 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  28%|█████████▏                       | 92/330 [25:24<1:13:42, 18.58s/it]
# Error: 500 Internal error encountered.
# Generating genres:  29%|█████████▌                       | 96/330 [26:44<1:13:58, 18.97s/it]
# Error: list index out of range
# Generating genres:  29%|█████████▋                       | 97/330 [26:56<1:06:15, 17.06s/it]
# Error: list index out of range
# Generating genres:  32%|███████████                       | 107/330 [29:11<50:15, 13.52s/it]
# Error: 500 Internal error encountered.
# Generating genres:  47%|████████████████                  | 156/330 [40:10<38:47, 13.38s/it]
# Error: list index out of range
# Generating genres:  48%|████████████████▏                 | 157/330 [40:24<38:45, 13.44s/it]
# Error: 400 Unable to submit request because the input token count is 59594 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  48%|████████████████▎                 | 158/330 [40:37<38:27, 13.41s/it]
# Error: 500 Internal error encountered.
# Generating genres:  50%|████████████████▉                 | 164/330 [42:00<37:18, 13.48s/it]
# Error: 500 Internal error encountered.
# Generating genres:  51%|█████████████████▍                | 169/330 [43:10<36:18, 13.53s/it]
# Error: 500 Internal error encountered.
# Generating genres:  52%|█████████████████▌                | 170/330 [43:31<41:48, 15.68s/it]
# Error: 400 Unable to submit request because the input token count is 34863 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  52%|█████████████████▊                | 173/330 [44:11<37:04, 14.17s/it]
# Error: 500 Internal error encountered.
# Generating genres:  53%|█████████████████▉                | 174/330 [44:27<38:45, 14.91s/it]
# Error: 500 Internal error encountered.
# Generating genres:  53%|██████████████████                | 175/330 [44:48<42:54, 16.61s/it]
# Error: 400 Unable to submit request because the input token count is 47906 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  54%|█████████████████▏              | 177/330 [45:49<1:03:36, 24.94s/it]
# Error: 500 Internal error encountered.
# Generating genres:  54%|██████████████████▍               | 179/330 [46:19<49:30, 19.67s/it]
# Error: 500 Internal error encountered.
# Generating genres:  55%|██████████████████▌               | 180/330 [46:43<52:45, 21.10s/it]
# Error: 400 Unable to submit request because the input token count is 98952 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  56%|██████████████████▉               | 184/330 [47:52<45:59, 18.90s/it]
# Error: 500 Internal error encountered.
# Generating genres:  56%|███████████████████               | 185/330 [48:09<44:33, 18.44s/it]
# Error: 500 Internal error encountered.
# Generating genres:  56%|███████████████████▏              | 186/330 [48:25<42:03, 17.52s/it]
# Error: list index out of range
# Generating genres:  59%|███████████████████▉              | 194/330 [50:36<35:13, 15.54s/it]
# Error: 500 Internal error encountered.
# Generating genres:  59%|████████████████████              | 195/330 [50:57<38:17, 17.02s/it]
# Error: 400 Unable to submit request because the input token count is 45585 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  59%|████████████████████▏             | 196/330 [51:12<36:30, 16.35s/it]
# Error: 500 Internal error encountered.
# Generating genres:  60%|████████████████████▎             | 197/330 [51:27<35:38, 16.08s/it]
# Error: 500 Internal error encountered.
# Generating genres:  60%|████████████████████▍             | 198/330 [51:55<43:10, 19.63s/it]
# Error: 400 Unable to submit request because the input token count is 70824 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  60%|████████████████████▌             | 199/330 [52:11<40:50, 18.70s/it]
# Error: 400 Request contains an invalid argument.
# Generating genres:  61%|████████████████████▌             | 200/330 [52:25<37:02, 17.10s/it]
# Error: 500 Internal error encountered.
# Generating genres:  61%|████████████████████▋             | 201/330 [52:49<41:05, 19.11s/it]
# Error: 400 Unable to submit request because the input token count is 99007 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  62%|████████████████████▉             | 203/330 [53:23<38:46, 18.32s/it]
# Error: list index out of range
# Generating genres:  62%|█████████████████████             | 204/330 [53:41<38:35, 18.38s/it]
# Error: 400 Unable to submit request because the input token count is 391753 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  63%|█████████████████████▌            | 209/330 [54:49<29:05, 14.43s/it]
# Error: list index out of range
# Generating genres:  64%|█████████████████████▋            | 210/330 [55:02<28:19, 14.16s/it]
# Error: 400 Unable to submit request because the input token count is 115557 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  65%|█████████████████████▉            | 213/330 [55:45<27:50, 14.28s/it]
# Error: 500 Internal error encountered.
# Generating genres:  65%|██████████████████████▎           | 216/330 [56:34<28:34, 15.04s/it]
# Error: list index out of range
# Generating genres:  66%|██████████████████████▎           | 217/330 [56:48<28:06, 14.93s/it]
# Error: 400 Unable to submit request because the input token count is 175956 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  66%|██████████████████████▍           | 218/330 [57:17<35:35, 19.07s/it]
# Error: 400 Unable to submit request because the input token count is 51250 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  66%|██████████████████████▌           | 219/330 [57:40<37:28, 20.26s/it]
# Error: 500 Internal error encountered.
# Generating genres:  67%|██████████████████████▋           | 220/330 [58:07<40:36, 22.15s/it]
# Error: 400 Unable to submit request because the input token count is 37169 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  67%|██████████████████████▊           | 221/330 [58:21<35:39, 19.63s/it]
# Error: 500 Internal error encountered.
# Generating genres:  67%|██████████████████████▊           | 222/330 [58:45<37:47, 20.99s/it]
# Error: 400 Unable to submit request because the input token count is 70941 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  68%|███████████████████████▏          | 225/330 [59:27<28:28, 16.27s/it]
# Error: 500 Internal error encountered.
# Generating genres:  69%|███████████████████████▍          | 227/330 [59:57<26:35, 15.49s/it]
# Error: 500 Internal error encountered.
# Generating genres:  69%|██████████████████████          | 228/330 [1:00:20<30:28, 17.93s/it]
# Error: 400 Unable to submit request because the input token count is 76939 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  70%|██████████████████████▍         | 232/330 [1:01:29<30:25, 18.63s/it]
# Error: 500 Internal error encountered.
# Generating genres:  72%|██████████████████████▉         | 237/330 [1:02:40<22:56, 14.80s/it]
# Error: list index out of range
# Generating genres:  72%|███████████████████████         | 238/330 [1:03:02<25:45, 16.79s/it]
# Error: 400 Unable to submit request because the input token count is 521288 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  72%|███████████████████████▏        | 239/330 [1:03:18<25:26, 16.78s/it]
# Error: list index out of range
# Generating genres:  73%|███████████████████████▎        | 240/330 [1:03:35<25:01, 16.68s/it]
# Error: 400 Unable to submit request because the input token count is 257365 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  73%|███████████████████████▎        | 241/330 [1:04:09<32:44, 22.07s/it]
# Error: 400 Unable to submit request because the input token count is 266202 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  73%|███████████████████████▍        | 242/330 [1:04:43<37:14, 25.39s/it]
# Error: 400 Unable to submit request because the input token count is 281060 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  74%|███████████████████████▌        | 243/330 [1:05:17<40:53, 28.20s/it]
# Error: 500 Internal error encountered.
# Generating genres:  74%|███████████████████████▋        | 244/330 [1:05:51<42:56, 29.95s/it]
# Error: 400 Unable to submit request because the input token count is 269192 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  74%|███████████████████████▊        | 245/330 [1:06:14<39:20, 27.77s/it]
# Error: 400 Unable to submit request because the input token count is 34124 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  75%|███████████████████████▊        | 246/330 [1:06:29<33:33, 23.97s/it]
# Error: 500 Internal error encountered.
# Generating genres:  75%|███████████████████████▉        | 247/330 [1:06:50<31:49, 23.00s/it]
# Error: 400 Unable to submit request because the input token count is 56828 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  77%|████████████████████████▋       | 254/330 [1:08:41<22:07, 17.47s/it]
# Error: 500 Internal error encountered.
# Generating genres:  77%|████████████████████████▋       | 255/330 [1:08:54<20:10, 16.14s/it]
# Error: 400 Unable to submit request because the input token count is 44727 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  78%|████████████████████████▊       | 256/330 [1:09:11<20:00, 16.22s/it]
# Error: 500 Internal error encountered.
# Generating genres:  78%|█████████████████████████       | 258/330 [1:09:41<18:45, 15.63s/it]
# Error: 500 Internal error encountered.
# Generating genres:  78%|█████████████████████████       | 259/330 [1:10:02<20:17, 17.15s/it]
# Error: 400 Unable to submit request because the input token count is 43746 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  80%|█████████████████████████▌      | 263/330 [1:11:02<16:44, 14.99s/it]
# Error: 500 Internal error encountered.
# Generating genres:  80%|█████████████████████████▋      | 265/330 [1:11:33<16:18, 15.05s/it]
# Error: 500 Internal error encountered.
# Generating genres:  81%|█████████████████████████▊      | 266/330 [1:11:53<17:43, 16.62s/it]
# Error: 400 Unable to submit request because the input token count is 36718 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  82%|██████████████████████████▎     | 271/330 [1:13:11<15:26, 15.70s/it]
# Error: 500 Internal error encountered.
# Generating genres:  83%|██████████████████████████▍     | 273/330 [1:13:52<17:26, 18.36s/it]
# Error: 500 Internal error encountered.
# Generating genres:  83%|██████████████████████████▌     | 274/330 [1:14:18<19:09, 20.52s/it]
# Error: 400 Unable to submit request because the input token count is 35224 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  83%|██████████████████████████▋     | 275/330 [1:14:35<17:49, 19.44s/it]
# Error: 500 Internal error encountered.
# Generating genres:  84%|██████████████████████████▊     | 276/330 [1:14:48<15:54, 17.68s/it]
# Error: 400 Unable to submit request because the input token count is 90094 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  84%|██████████████████████████▊     | 277/330 [1:15:02<14:35, 16.51s/it]
# Error: 500 Internal error encountered.
# Generating genres:  85%|███████████████████████████     | 279/330 [1:15:49<17:30, 20.59s/it]
# Error: 500 Internal error encountered.
# Generating genres:  85%|███████████████████████████▏    | 280/330 [1:16:19<19:31, 23.43s/it]
# Error: 400 Unable to submit request because the input token count is 94950 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  85%|███████████████████████████▏    | 281/330 [1:16:46<20:02, 24.54s/it]
# Error: 400 Unable to submit request because the input token count is 100443 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  85%|███████████████████████████▎    | 282/330 [1:17:15<20:47, 25.99s/it]
# Error: 500 Internal error encountered.
# Generating genres:  86%|███████████████████████████▍    | 283/330 [1:17:32<18:09, 23.17s/it]
# Error: 500 Internal error encountered.
# Generating genres:  86%|███████████████████████████▌    | 284/330 [1:18:03<19:41, 25.68s/it]
# Error: 400 Unable to submit request because the input token count is 117306 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  87%|███████████████████████████▋    | 286/330 [1:18:44<16:53, 23.03s/it]
# Error: 500 Internal error encountered.
# Generating genres:  89%|████████████████████████████▍   | 293/330 [1:20:39<09:26, 15.31s/it]
# Error: 500 Internal error encountered.
# Generating genres:  89%|████████████████████████████▌   | 294/330 [1:21:00<10:05, 16.83s/it]
# Error: 400 Unable to submit request because the input token count is 48223 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Error: 500 Internal error encountered.
# Generating genres:  92%|█████████████████████████████▎  | 302/330 [1:23:04<07:40, 16.44s/it]
# Error: 500 Internal error encountered.
# Generating genres:  92%|█████████████████████████████▍  | 303/330 [1:23:32<08:53, 19.75s/it]
# Error: 400 Unable to submit request because the input token count is 183637 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  92%|█████████████████████████████▌  | 305/330 [1:23:59<06:54, 16.58s/it]
# Error: list index out of range
# Generating genres:  94%|█████████████████████████████▉  | 309/330 [1:24:55<05:04, 14.51s/it]
# Error: 500 Internal error encountered.
# Generating genres:  95%|██████████████████████████████▌ | 315/330 [1:26:21<03:28, 13.92s/it]
# Error: 500 Internal error encountered.
# Generating genres:  96%|██████████████████████████████▋ | 316/330 [1:26:45<03:57, 16.98s/it]
# Error: 400 Unable to submit request because the input token count is 84907 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  97%|███████████████████████████████▏| 321/330 [1:27:53<02:08, 14.30s/it]
# Error: 500 Internal error encountered.
# Generating genres:  98%|███████████████████████████████▏| 322/330 [1:28:14<02:09, 16.14s/it]
# Error: 400 Unable to submit request because the input token count is 42237 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  98%|███████████████████████████████▎| 323/330 [1:28:27<01:47, 15.40s/it]
# Error: 500 Internal error encountered.
# Generating genres:  98%|███████████████████████████████▍| 324/330 [1:28:51<01:47, 17.86s/it]
# Error: 400 Unable to submit request because the input token count is 81511 but model only supports up to 32766. Reduce the input token count and try again. You can also use the CountTokens API to calculate prompt token count and billable characters. Learn more: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models
# Generating genres:  99%|███████████████████████████████▋| 327/330 [1:29:43<00:51, 17.31s/it]
# Error: 500 Internal error encountered.
# Generating genres: 100%|████████████████████████████████| 330/330 [1:30:32<00:00, 16.46s/it]

# %%
df = df.dropna()
df["genres"] = df["genres"].map(lambda x: x.strip().lower().split(", "))

# %%
df_explode = df.explode("genres")
df_explode = df_explode[df_explode["genres"] != ""]
genre_trends = df_explode.groupby(["year", "genres"]).size().unstack(fill_value=0)
filtered_genre_trends = genre_trends[genre_trends.sum().sort_values()[-10:].index]
percentage_filtered_genre_trends = (
    filtered_genre_trends.divide(filtered_genre_trends.sum(axis=1), axis=0) * 100
)
percentage_filtered_genre_trends.dropna()
percentage_filtered_genre_trends = percentage_filtered_genre_trends.reset_index()
melted_percentage_filtered_genre_trends = percentage_filtered_genre_trends.melt(
    id_vars="year", var_name="genre", value_name="popularity"
)

# %%
so.Plot(
    melted_percentage_filtered_genre_trends, "year", "popularity", color="genre"
).add(so.Area(alpha=0.7), so.Stack())

# %%
window_size = 7

melted_percentage_filtered_genre_trends["popularity_smoothed"] = (
    melted_percentage_filtered_genre_trends.groupby("genre")["popularity"].transform(
        lambda x: x.rolling(window=window_size, center=True).mean()
    )
)

so.Plot(
    melted_percentage_filtered_genre_trends,
    "year",
    "popularity_smoothed",
    color="genre",
).add(so.Area(alpha=0.7), so.Stack()).layout(size=(16, 9)).save(
    "test.png", bbox_inches="tight"
)

# %%
# gemini_pro_long.generate_content(
#     "\"The play portrays the visit of an elderly professor and his glamorous, much younger second wife, Yelena, to the rural estate that supports their urban lifestyle. Two friends—Vanya, brother of the professor's late first wife, who has long managed the estate, and Astrov, the local doctor—both fall under Yelena's spell while bemoaning the ennui of their provincial existence. Sonya, the professor's daughter by his first wife, who has worked with Vanya to keep the estate going, suffers from her unrequited feelings for Astrov. Matters are brought to a crisis when the professor announces his intention to sell the estate, Vanya and Sonya's home, with a view to investing the proceeds to achieve a higher income for himself and his wife.\"\nRepeat each sentance with a catigorization after: horror short story humor social commentary satire fiction historical tragedy romance drama"
# ).candidates[0].content.parts[0].text

# %%
# gemini_pro_long.generate_content(
#     "\"The play portrays the visit of an elderly professor and his glamorous, much younger second wife, Yelena, to the rural estate that supports their urban lifestyle. Two friends—Vanya, brother of the professor's late first wife, who has long managed the estate, and Astrov, the local doctor—both fall under Yelena's spell while bemoaning the ennui of their provincial existence. Sonya, the professor's daughter by his first wife, who has worked with Vanya to keep the estate going, suffers from her unrequited feelings for Astrov. Matters are brought to a crisis when the professor announces his intention to sell the estate, Vanya and Sonya's home, with a view to investing the proceeds to achieve a higher income for himself and his wife.\"\nRewrite the abstract like Uncle Vanya was a political commentary satire of Russia in 1870:"
# ).candidates[0].content.parts[0].text
